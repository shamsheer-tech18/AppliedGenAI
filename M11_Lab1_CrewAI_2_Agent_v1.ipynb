# %% [markdown]
# <a href="https://colab.research.google.com/github/shamsheer-tech18/AppliedGenAI/blob/main/M11_Lab1_CrewAI_2_Agent_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>CrewAI Lab</title>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background-color: #f8fbff;
#       color: #222;
#       padding: 30px;
#       line-height: 1.6;
#     }
#
#     h1, h2 {
#       color: #1e4b8f;
#     }
#
#     a {
#       color: #1e4b8f;
#       text-decoration: none;
#     }
#
#     a:hover {
#       text-decoration: underline;
#     }
#
#     .center {
#       text-align: center;
#     }
#
#     .title-img {
#       width: 600px;
#       max-width: 100%;
#       margin-bottom: 20px;
#     }
#
#     .table-container {
#       overflow-x: auto;
#       margin-top: 20px;
#     }
#
#     table {
#       border-collapse: collapse;
#       width: 100%;
#       background-color: #fff;
#       box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#     }
#
#     th, td {
#       padding: 12px 16px;
#       text-align: left;
#       border-bottom: 1px solid #e0e0e0;
#     }
#
#     th {
#       background-color: #e6f0fb;
#       color: #1e4b8f;
#     }
#
#     ul {
#       margin-top: 10px;
#     }
#   </style>
# </head>
# <body>
#
#   <div class="center">
#     <img src="https://www.dropbox.com/scl/fi/72c3k12bjnhxdebypttum/crewAI_title.png?dl=1" alt="crewAI Title" class="title-img">
#   </div>
#
#   <h1>Welcome to the CrewAI Lab</h1>
#
#   <p>
#     This lab introduces <strong>CrewAI</strong>, a powerful platform for orchestrating collaborative AI agents, and explores its integration with LangChain and n8n.
#     Visit the <a href="https://www.crewai.com/" target="_blank">CrewAI website</a> to learn more about how CrewAI empowers teams to build complex, automated workflows and advanced_

# %% [markdown]
# # 🤖 CrewAI 2-Agent Tutorial
# ## What is CrewAI?
#
# **CrewAI** is a Python framework that creates teams of AI agents working together. Think of it as hiring specialists - each agent has a specific role and expertise.
#
# ### 🏗️ Core Components:
# 1. **🤖 Agents**: AI team members with specific roles
# 2. **📋 Tasks**: Individual assignments
# 3. **👥 Crew**: Manages the team workflow
# 4. **🔧 Tools**: Special abilities (web search, calculations, etc.)
#
# ---

# %%
# +++++ 🎨 Pretty Print Utility
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Create styled message boxes for better visual output in Colab

from IPython.display import display, HTML

def pretty_print(text, title="ℹ️ Info", theme="blue"):
    """Displays a styled message box with optional color themes: blue, red, or yellow."""

    themes = {
        "blue": {"color": "#1e4b8f", "background": "#f0f6ff"},
        "red": {"color": "#c62828", "background": "#ffebee"},
        "yellow": {"color": "#b26a00", "background": "#fff8e1"}
    }

    style = themes.get(theme.lower(), themes["blue"])
    formatted_text = text.replace('\n', '<br>')

    display(HTML(f"""
    <div style="border-left: 5px solid {style['color']}; padding: 12px 16px; background-color: {style['background']};
                border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
        <strong style="color: {style['color']}; font-size: 16px;">{title}</strong><br>
        <span style="font-size: 14px; color: #333;">{formatted_text}</span>
    </div>
    """))

print("🎨 Pretty print utility ready!")
# Out:
# 🎨 Pretty print utility ready!

# %%
# +++++ 📦 Installation & API Setup
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Install packages and setup secure API key

# !pip install crewai crewai-tools -q

try:
    from google.colab import userdata
    import os
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
    pretty_print("🔐 API key loaded successfully!", "✅ Setup Complete", "blue")
except:
    pretty_print("⚠️ Please set OPENAI_API_KEY in Colab → More → Secrets", "❌ Missing API Key", "red")
# Out:
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">✅ Setup Complete</strong><br>
#         <span style="font-size: 14px; color: #333;">🔐 API key loaded successfully!</span>
#     </div>

# %% [markdown]
# ## 🤖 Defining Agents in CrewAI
#
# In CrewAI, each **agent** represents an autonomous expert responsible for a specific task.
# You define agents using three main components:
#
# - **Role 🎯:** Clearly describes the agent's professional role or expertise.
# - **Goal 🎯:** Defines the specific objective the agent should achieve.
# - **Backstory 📖:** Provides a short narrative about the agent’s expertise or experience, giving context to their behavior.
# ## Understanding 2-Agent System
#
# We'll create **2 specialized agents**:
# - **🔍 Research Agent**: Gathers information using web search
# - **📝 Analysis Agent**: Analyzes and summarizes findings

# %%
# +++++ 🤖 Creating 2 Generalized Agents (NO TOOLS)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Define two generalized agents that can handle any topic

from crewai import Agent

# 🔍 Agent 1: Research Agent (Generalized)
research_agent = Agent(
    role="Research Specialist",
    goal="Gather comprehensive information about any given topic using existing knowledge",
    backstory="""You are an experienced researcher with broad knowledge across many fields.
    You excel at providing detailed, accurate information on various topics from your training data.""",
    verbose=True,
    allow_delegation=False
)

# 📝 Agent 2: Analysis Agent (Generalized)
analysis_agent = Agent(
    role="Content Analyst",
    goal="Analyze and summarize information into clear, concise insights",
    backstory="""You are an expert analyst who can synthesize complex information into
    actionable insights. You excel at creating structured summaries and key takeaways.""",
    verbose=True,
    allow_delegation=False
)

pretty_print("🤖 Two generalized agents created successfully!\n🔍 Research Agent - Gathers information\n📝 Analysis Agent - Synthesizes findings\n\n⚠️ Note: No tools yet - agents use existing knowledge", "✅ Agents Ready", "blue")
# Out:
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">✅ Agents Ready</strong><br>
#         <span style="font-size: 14px; color: #333;">🤖 Two generalized agents created successfully!<br>🔍 Research Agent - Gathers information<br>📝 Analysis Agent - Synthesizes findings<br><br>⚠️ Note: No tools yet - agents use existing knowledge</span>
#     </div>

# %% [markdown]
# ## 📋 What is a Task?
#
# In CrewAI, a **Task** is a unit of work assigned to an agent. It describes what the agent should do and what kind of output is expected.
#
# ## 🛠️ What’s happening here?
#
# We define two tasks:
# - A **Research Task** asking the agent to gather detailed facts about the topic.
# - An **Analysis Task** asking another agent to summarize and interpret the findings.
#
# The `TOPIC` variable makes both tasks reusable for any subject by simply changing one line.

# %%
# +++++ 📋 Creating Tasks with Topic Variable
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

from crewai import Task  # Only import Task here

# Define your topic of interest
TOPIC = "Harvard University's impact on education and Nobel Prize connections"

# 🧠 Task 1: Research Task
research_task = Task(
    description=f"""Research the topic: {TOPIC}

    Provide comprehensive information including:
    1. Key facts and background information
    2. Important developments and achievements
    3. Current status and recent updates
    4. Significance and impact

    Use your existing knowledge to provide accurate, detailed information.""",
    expected_output="Comprehensive research findings about the topic",
    agent=research_agent
)

# 🔎 Task 2: Analysis Task
analysis_task = Task(
    description=f"""Analyze the research findings about: {TOPIC}

    Create a structured summary with:
    1. One paragraph overview (3-4 sentences)
    2. 3-4 key bullet points highlighting main insights
    3. Brief conclusion about significance

    Keep responses concise and well-structured.""",
    expected_output="A structured analysis with paragraph summary and bullet points",
    agent=analysis_agent
)

pretty_print("📋 Tasks created for research and analysis", "✅ Tasks Ready", "blue")
# Out:
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">✅ Tasks Ready</strong><br>
#         <span style="font-size: 14px; color: #333;">📋 Tasks created for research and analysis</span>
#     </div>

# %% [markdown]
# ## 🧑‍🤝‍🧑 What is a Crew?
#
# A **Crew** is a group of agents and tasks that work together. It manages who does what and how tasks are coordinated.
#
# ## 🛠️ What’s happening here?
#
# We create a crew with:
# - Two agents: one for research, one for analysis.
# - Two tasks: assigned to those agents.
#
# The crew uses delegation and iteration (`max_iter=3`) to complete the full job.

# %%
# +++++ 🧑‍🤝‍🧑 Creating Crew with Agents and Tasks
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

from crewai import Crew  # Only import Crew here

# Create a crew that includes the two tasks and corresponding agents
education_crew = Crew(
    agents=[research_agent, analysis_agent],
    tasks=[research_task, analysis_task],
    verbose=False,
    max_iter=1  # Reasonable number of coordination loops
)

pretty_print("🤖 Crew assembled with Research and Analysis agents", "✅ Crew Ready", "green")
# Out:
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">✅ Crew Ready</strong><br>
#         <span style="font-size: 14px; color: #333;">🤖 Crew assembled with Research and Analysis agents</span>
#     </div>

# %% [markdown]
# ## 🚀 What is Crew Execution?
#
# **Execution** means running the crew — agents perform their tasks in order and produce a final result.
#
# ## 🛠️ What’s happening here?
#
# - We start execution using `.kickoff()`
# - The research and analysis agents complete their tasks
# - The result is printed with `pretty_print` for clear display
#
# The current topic is shown for reference, so you always know what the crew is working on.

# %%
# +++++ 🚀 Execute the Crew on Selected Topic
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# Use the previously defined topic and crew
pretty_print(f"🎯 Running crew for topic: {TOPIC}", "🚀 Execution Started", "yellow")

# Run the crew and store the result
crew_result = education_crew.kickoff()

# Display the result - Convert to string first!
pretty_print(str(crew_result), "🧠 Final Output", "blue")
# Out:
#     <div style="border-left: 5px solid #b26a00; padding: 12px 16px; background-color: #fff8e1;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #b26a00; font-size: 16px;">🚀 Execution Started</strong><br>
#         <span style="font-size: 14px; color: #333;">🎯 Running crew for topic: Harvard University's impact on education and Nobel Prize connections</span>
#     </div>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Research the topic: Harvard University's impact on education and Nobel Prize connections                 │
# │                                                                                                                 │
# │      Provide comprehensive information including:                                                               │
# │      1. Key facts and background information                                                                    │
# │      2. Important developments and achievements                                                                 │
# │      3. Current status and recent updates                                                                       │
# │      4. Significance and impact                                                                                 │
# │                                                                                                                 │
# │      Use your existing knowledge to provide accurate, detailed information.                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Harvard University's Impact on Education and Nobel Prize Connections                                           │
# │                                                                                                                 │
# │  1. Key Facts and Background Information                                                                        │
# │                                                                                                                 │
# │  Harvard University, established in 1636, is the oldest institution of higher education in the United States    │
# │  and one of the most prestigious universities globally. Located in Cambridge, Massachusetts, Harvard is         │
# │  renowned for its rigorous academic programs, influential faculty, and extensive research activities. With a    │
# │  mission to cultivate knowledge and contribute to society, Harvard has played a central role in shaping modern  │
# │  education and research on various disciplines.                                                                 │
# │                                                                                                                 │
# │  Harvard's structure comprises multiple schools, including Harvard College (undergraduate), Harvard Business    │
# │  School, Harvard Law School, Harvard Medical School, Harvard Graduate School of Arts and Sciences, and others.  │
# │  This diversity facilitates interdisciplinary education and fosters innovation.                                 │
# │                                                                                                                 │
# │  2. Important Developments and Achievements                                                                     │
# │                                                                                                                 │
# │  Educational Impact:                                                                                            │
# │  - Harvard has been a pioneer in liberal arts education, emphasizing critical thinking, creativity, and         │
# │  broad-based knowledge.                                                                                         │
# │  - It introduced the elective system in the late 19th century under President Charles W. Eliot, allowing        │
# │  students to customize their education—a model widely adopted across higher education.                          │
# │  - The university has contributed to the development of numerous disciplines in the humanities, sciences, law,  │
# │  business, medicine, and social sciences.                                                                       │
# │  - Harvard Extension School and Harvard Online Learning have expanded access to education globally.             │
# │  - It has produced many prominent educators, scholars, policymakers, and leaders who have shaped educational    │
# │  standards worldwide.                                                                                           │
# │                                                                                                                 │
# │  Research and Innovation:                                                                                       │
# │  - Harvard is a top-tier research institution, consistently ranked among the best globally for research output  │
# │  and funding.                                                                                                   │
# │  - It hosts extensive research centers facilitating advances in medicine, technology, economics, physics, and   │
# │  social sciences.                                                                                               │
# │  - The university has historically supported groundbreaking scientific work, including early developments in    │
# │  computer science, genomics, and artificial intelligence.                                                       │
# │                                                                                                                 │
# │  Nobel Prize Connections:                                                                                       │
# │  - Harvard University has a distinguished record regarding Nobel Prizes:                                        │
# │    - More than 160 Nobel laureates have been affiliated with Harvard as faculty, researchers, or alumni.        │
# │    - These laureates have earned awards across categories including Medicine, Physics, Chemistry, Peace,        │
# │  Economics, and Literature.                                                                                     │
# │    - Renowned Nobel Prize winners connected to Harvard include Al Gore (Peace, 2007), Amartya Sen (Economics,   │
# │  1998), and E.O. Wilson (two-time winner in Medicine and Peace-related fields).                                 │
# │    - Harvard’s Nobel affiliates have contributed fundamentally to fields such as economics (e.g., development   │
# │  economics and behavioral economics), medicine (breakthroughs in genetics and immunology), and physics          │
# │  (quantum mechanics, particle physics).                                                                         │
# │                                                                                                                 │
# │  3. Current Status and Recent Updates                                                                           │
# │                                                                                                                 │
# │  - Harvard continues to be at the forefront of educational innovation and research excellence.                  │
# │  - It invests heavily in interdisciplinary research initiatives, such as the Harvard Data Science Initiative    │
# │  and the Harvard Quantum Initiative, advancing emerging scientific frontiers.                                   │
# │  - The university has expanded diversity and inclusion efforts in its admissions, faculty recruitment, and      │
# │  scholarship programs.                                                                                          │
# │  - Recent Nobel laureates affiliated with Harvard include David Julius and Ardem Patapoutian (2021 Nobel Prize  │
# │  in Medicine) for discoveries related to sensory receptors.                                                     │
# │  - Harvard is enhancing its global influence through partnerships, online education programs (e.g., HarvardX    │
# │  on edX), and engagement with international research projects.                                                  │
# │  - The university is also focusing on climate change research and sustainability, spearheading efforts through  │
# │  the Harvard University Center for the Environment.                                                             │
# │                                                                                                                 │
# │  4. Significance and Impact                                                                                     │
# │                                                                                                                 │
# │  Educational Significance:                                                                                      │
# │  - Harvard’s model of liberal arts education and research-intensive university has influenced the global        │
# │  higher education landscape.                                                                                    │
# │  - Its commitment to cultivating broad knowledge and critical inquiry has set educational standards and         │
# │  inspired the development of numerous prestigious institutions worldwide.                                       │
# │  - Harvard alumni have founded and led some of the world’s major corporations, governments, and cultural        │
# │  institutions, broadly impacting society through education and leadership.                                      │
# │  - The university’s emphasis on multidisciplinary study fosters innovation by bridging fields.                  │
# │                                                                                                                 │
# │  Research Impact:                                                                                               │
# │  - Fundamental scientific breakthroughs associated with Harvard have transformed medicine, technology,          │
# │  economics, and environmental science.                                                                          │
# │  - Harvard’s Nobel laureates embody the university’s role as a cradle of innovation and intellectual            │
# │  leadership.                                                                                                    │
# │  - The research conducted under Harvard’s auspices frequently informs policy, industry development, and the     │
# │  global scientific community.                                                                                   │
# │                                                                                                                 │
# │  Global Influence:                                                                                              │
# │  - Harvard’s reputation and resources enable it to attract top talent globally, creating a dynamic              │
# │  international academic community.                                                                              │
# │  - Its expansive alumni network exerts significant influence in education, politics, and business worldwide.    │
# │  - Through its educational outreach and research collaborations, Harvard contributes to addressing global       │
# │  challenges such as public health, climate change, and economic development.                                    │
# │                                                                                                                 │
# │  In summary, Harvard University stands as a seminal institution in the history of education and research. Its   │
# │  continuous contributions to knowledge, its revolutionary impact on educational paradigms, and its              │
# │  unparalleled record of Nobel Prize affiliations underscore its role as a global leader in advancing human      │
# │  understanding and societal progress.                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Analyst                                                                                         │
# │                                                                                                                 │
# │  Task: Analyze the research findings about: Harvard University's impact on education and Nobel Prize            │
# │  connections                                                                                                    │
# │                                                                                                                 │
# │      Create a structured summary with:                                                                          │
# │      1. One paragraph overview (3-4 sentences)                                                                  │
# │      2. 3-4 key bullet points highlighting main insights                                                        │
# │      3. Brief conclusion about significance                                                                     │
# │                                                                                                                 │
# │      Keep responses concise and well-structured.                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Analyst                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Harvard University, established in 1636, is the oldest and one of the most prestigious higher education        │
# │  institutions in the United States. It has significantly influenced modern education through innovations like   │
# │  the elective system and its commitment to liberal arts education, fostering critical thinking and              │
# │  interdisciplinary study. Harvard’s extensive research output and global initiatives have led to breakthroughs  │
# │  across many disciplines. The university's affiliation with over 160 Nobel laureates highlights its             │
# │  outstanding role in advancing knowledge and shaping global intellectual leadership.                            │
# │                                                                                                                 │
# │  - Harvard pioneered liberal arts education and the elective system, shaping global higher education standards  │
# │  and promoting broad-based, interdisciplinary learning.                                                         │
# │  - The university is a leading research powerhouse, with major contributions in medicine, economics, physics,   │
# │  computer science, and environmental science.                                                                   │
# │  - Harvard boasts more than 160 Nobel laureates among its faculty, researchers, and alumni, including notable   │
# │  figures such as Al Gore, Amartya Sen, and E.O. Wilson, reflecting its broad impact across Nobel categories.    │
# │  - Recent efforts emphasize diversity, inclusion, sustainability, and global educational outreach through       │
# │  initiatives like HarvardX and interdisciplinary research centers focusing on emerging scientific fields.       │
# │                                                                                                                 │
# │  In conclusion, Harvard University’s enduring legacy in education and research, underscored by its record of    │
# │  Nobel Prize affiliations, cements its status as a global leader. Its innovations in educational models,        │
# │  high-impact scientific discoveries, and extensive international influence contribute significantly to          │
# │  societal progress and global knowledge advancement.                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">🧠 Final Output</strong><br>
#         <span style="font-size: 14px; color: #333;">Harvard University, established in 1636, is the oldest and one of the most prestigious higher education institutions in the United States. It has significantly influenced modern education through innovations like the elective system and its commitment to liberal arts education, fostering critical thinking and interdisciplinary study. Harvard’s extensive research output and global initiatives have led to breakthroughs across many disciplines. The university's affiliation with over 160 Nobel laureates highlights its outstanding role in advancing knowledge and shaping global intellectual leadership.<br><br>- Harvard pioneered liberal arts education and the elective system, shaping global higher education standards and promoting broad-based, interdisciplinary learning.<br>- The university is a leading research powerhouse, with major contributions in medicine, economics, physics, computer science, and environmental science.<br>- Harvard boasts more than 160 Nobel laureates among its faculty, researchers, and alumni, including notable figures such as Al Gore, Amartya Sen, and E.O. Wilson, reflecting its broad impact across Nobel categories.<br>- Recent efforts emphasize diversity, inclusion, sustainability, and global educational outreach through initiatives like HarvardX and interdisciplinary research centers focusing on emerging scientific fields.<br><br>In conclusion, Harvard University’s enduring legacy in education and research, underscored by its record of Nobel Prize affiliations, cements its status as a global leader. Its innovations in educational models, high-impact scientific discoveries, and extensive international influence contribute significantly to societal progress and global knowledge advancement.</span>
#     </div>

# %%
# +++++ 🧪 Hands-On: Test with Different Topics
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Test the generalized agents with any topic you want

def analyze_topic(topic):
    """Analyze any topic using our 2-agent crew"""

    research_task_custom = Task(
        description=f"""Research the topic: {topic}

        Provide comprehensive information including:
        1. Key facts and background information
        2. Important developments and achievements
        3. Current status and recent context
        4. Significance and impact

        Use your existing knowledge to provide accurate information.""",
        expected_output=f"Research findings about: {topic}",
        agent=research_agent
    )

    analysis_task_custom = Task(
        description=f"""Analyze the research findings about: {topic}

        Create a structured summary with:
        1. One paragraph overview (3-4 sentences)
        2. 3-4 key bullet points
        3. Brief significance statement

        Keep it concise and well-structured.""",
        expected_output="Structured analysis with summary and key points",
        agent=analysis_agent
    )

    topic_crew = Crew(
        agents=[research_agent, analysis_agent],
        tasks=[research_task_custom, analysis_task_custom],
        verbose=False
    )

    result = topic_crew.kickoff()
    pretty_print(str(result), f"📋 Analysis: {topic}", "blue")
    return result

# 🎯 Test different topics - try these!
#print("🎯 Try these example topics:")
#print('analyze_topic("Climate Change and Global Warming")')
#print('analyze_topic("Artificial Intelligence in Healthcare")')
#print('analyze_topic("Space Exploration and Mars Missions")')
#print('analyze_topic("Renewable Energy Technologies")')

# Example: Uncomment to test
analyze_topic("Artificial Intelligence in Healthcare")
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Research the topic: Artificial Intelligence in Healthcare                                                │
# │                                                                                                                 │
# │          Provide comprehensive information including:                                                           │
# │          1. Key facts and background information                                                                │
# │          2. Important developments and achievements                                                             │
# │          3. Current status and recent context                                                                   │
# │          4. Significance and impact                                                                             │
# │                                                                                                                 │
# │          Use your existing knowledge to provide accurate information.                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Research findings about: Artificial Intelligence in Healthcare                                                 │
# │                                                                                                                 │
# │  1. Key Facts and Background Information                                                                        │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) in healthcare refers to the application of machine learning algorithms, natural   │
# │  language processing, robotics, and data analytics to assist in diagnosis, treatment, patient monitoring, and   │
# │  healthcare management. AI systems can process and analyze large volumes of health data to extract meaningful   │
# │  insights that help healthcare professionals make more informed decisions.                                      │
# │                                                                                                                 │
# │  The roots of AI in healthcare trace back to early expert systems in the 1970s, such as MYCIN, which was        │
# │  designed to diagnose bacterial infections. However, due to data limitations and computational power            │
# │  constraints, early AI applications were limited in scope and effectiveness. The recent explosion of digital    │
# │  health data, improvements in computational resources, and advances in machine learning methods, particularly   │
# │  deep learning, have propelled AI to the forefront of healthcare innovation.                                    │
# │                                                                                                                 │
# │  Healthcare data typically includes electronic health records (EHRs), medical imaging (radiology, pathology),   │
# │  genomic sequences, wearable device outputs, and clinical notes. AI leverages this data variety and volume to   │
# │  identify patterns that may not be visible to human clinicians, enabling predictive analytics, personalized     │
# │  medicine, and operational efficiencies.                                                                        │
# │                                                                                                                 │
# │  2. Important Developments and Achievements                                                                     │
# │                                                                                                                 │
# │  - Medical Imaging and Diagnostics: Deep learning models, especially convolutional neural networks (CNNs),      │
# │  have demonstrated remarkable accuracy in interpreting medical images such as X-rays, MRI, CT scans, and        │
# │  pathology slides. Notable achievements include AI systems that detect diabetic retinopathy with accuracy       │
# │  comparable to ophthalmologists, identify breast cancer from mammograms, and diagnose skin cancer from          │
# │  dermoscopic images.                                                                                            │
# │                                                                                                                 │
# │  - Natural Language Processing (NLP) in Clinical Documentation: AI-powered NLP tools have been developed to     │
# │  extract relevant information from unstructured clinical notes, assisting in codifying diagnoses, summarizing   │
# │  patient records, and facilitating clinical decision support.                                                   │
# │                                                                                                                 │
# │  - Predictive Analytics for Patient Outcomes: Machine learning algorithms are employed to predict patient       │
# │  deterioration, readmission risks, and disease progression. Hospitals use AI models to triage patients more     │
# │  effectively, allocate resources, and intervene earlier, potentially reducing mortality and morbidity.          │
# │                                                                                                                 │
# │  - Drug Discovery and Development: AI has accelerated drug discovery pipelines by predicting molecular          │
# │  interactions, optimizing candidate molecules, and analyzing biological data. Several AI-driven drug            │
# │  candidates have entered clinical testing phases more rapidly than traditional approaches.                      │
# │                                                                                                                 │
# │  - Robotics and Surgery: AI-enabled robotic systems assist surgeons by providing enhanced precision,            │
# │  stability, and real-time analytics during operations. Examples include the da Vinci Surgical System and AI     │
# │  guidance for minimally invasive procedures.                                                                    │
# │                                                                                                                 │
# │  - Virtual Health Assistants: AI-powered chatbots and virtual assistants help with patient engagement, symptom  │
# │  checking, appointment scheduling, and medication adherence.                                                    │
# │                                                                                                                 │
# │  Notable institutional and commercial players include IBM Watson Health (despite recent challenges), Google     │
# │  DeepMind, PathAI, Zebra Medical Vision, and Tempus Labs.                                                       │
# │                                                                                                                 │
# │  3. Current Status and Recent Context                                                                           │
# │                                                                                                                 │
# │  AI in healthcare is increasingly integrated into clinical workflows, though its adoption varies by region,     │
# │  healthcare system maturity, and domain. Regulatory bodies like the U.S. Food and Drug Administration (FDA)     │
# │  have developed frameworks to approve AI-based medical devices and software as a medical device (SaMD).         │
# │  Continuous learning AI models present challenges regarding validation, safety, and bias mitigation.            │
# │                                                                                                                 │
# │  Recent years have seen AI applications in pandemic response, including modeling COVID-19 spread, analyzing     │
# │  medical images for diagnosis, and accelerating vaccine research.                                               │
# │                                                                                                                 │
# │  Ethical concerns, such as data privacy, algorithmic transparency, bias, and health disparities, remain         │
# │  critical issues. Research is ongoing to ensure AI systems are explainable and equitable.                       │
# │                                                                                                                 │
# │  Interoperability between AI tools and existing electronic health record systems is a practical challenge.      │
# │  Additionally, clinicians require training to interpret AI outputs effectively.                                 │
# │                                                                                                                 │
# │  Federated learning and privacy-preserving AI techniques have emerged to enable collaborative model training    │
# │  without compromising patient data confidentiality.                                                             │
# │                                                                                                                 │
# │  4. Significance and Impact                                                                                     │
# │                                                                                                                 │
# │  AI has the potential to transform healthcare by enhancing diagnostic accuracy, personalizing treatment,        │
# │  optimizing operational efficiency, and enabling predictive medicine. By augmenting rather than replacing       │
# │  healthcare professionals, AI can reduce clinician burnout and improve patient outcomes.                        │
# │                                                                                                                 │
# │  Improved early detection of diseases through AI can enable timely interventions, lowering healthcare costs     │
# │  and improving quality of life. AI-driven drug discovery may shorten time-to-market for new therapies,          │
# │  benefitting patients with unmet medical needs.                                                                 │
# │                                                                                                                 │
# │  Population health management benefits from AI by identifying trends and risk factors to inform public health   │
# │  strategies.                                                                                                    │
# │                                                                                                                 │
# │  However, the significance of AI in healthcare depends on responsible implementation, robust validation, and    │
# │  addressing socio-ethical challenges. Balanced integration of AI tools, ensuring human oversight, and           │
# │  continuous evaluation will determine long-term impact.                                                         │
# │                                                                                                                 │
# │  Overall, AI is reshaping medicine by leveraging data at unprecedented scale and precision, promising a future  │
# │  of more efficient, effective, and equitable healthcare delivery.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Analyst                                                                                         │
# │                                                                                                                 │
# │  Task: Analyze the research findings about: Artificial Intelligence in Healthcare                               │
# │                                                                                                                 │
# │          Create a structured summary with:                                                                      │
# │          1. One paragraph overview (3-4 sentences)                                                              │
# │          2. 3-4 key bullet points                                                                               │
# │          3. Brief significance statement                                                                        │
# │                                                                                                                 │
# │          Keep it concise and well-structured.                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Analyst                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Artificial Intelligence (AI) in healthcare leverages advanced machine learning, natural language processing,   │
# │  robotics, and data analytics to improve diagnosis, treatment, patient monitoring, and management. With roots   │
# │  dating back to early expert systems in the 1970s, AI has recently accelerated due to expansive digital health  │
# │  data and enhanced computational capabilities, particularly through deep learning. AI processes diverse         │
# │  healthcare data, including electronic health records, medical imaging, genomics, and wearable device outputs,  │
# │  enabling new insights such as predictive analytics and personalized medicine. The integration of AI into       │
# │  clinical workflows continues to grow, despite ongoing challenges related to validation, ethics,                │
# │  interoperability, and training.                                                                                │
# │                                                                                                                 │
# │  Key Points:                                                                                                    │
# │  - Medical Imaging and Diagnostics: Deep learning models like convolutional neural networks (CNNs) have         │
# │  achieved accuracy on par with specialists in detecting conditions such as diabetic retinopathy, breast         │
# │  cancer, and skin cancer from imaging data.                                                                     │
# │  - Predictive Analytics and Clinical NLP: AI predicts patient outcomes (e.g., deterioration, readmission risk)  │
# │  and uses natural language processing to extract meaningful information from unstructured clinical notes,       │
# │  enhancing decision support.                                                                                    │
# │  - Drug Discovery and Robotics: AI accelerates drug development by predicting molecular interactions and        │
# │  supports surgical precision with robotics, exemplified by systems like da Vinci Surgical System.               │
# │  - Ethical and Implementation Challenges: Privacy, bias, algorithm transparency, and interoperability pose      │
# │  significant hurdles, with emerging solutions such as federated learning aimed at addressing data               │
# │  confidentiality and collaborative model training.                                                              │
# │                                                                                                                 │
# │  Significance:                                                                                                  │
# │  AI holds transformative potential to improve healthcare accuracy, efficiency, and personalization, reducing    │
# │  costs and enhancing patient outcomes by augmenting clinicians rather than replacing them. Its ability to       │
# │  analyze large-scale, complex health data enables earlier disease detection, faster drug development, and       │
# │  better population health management. However, realizing AI’s full benefits requires responsible deployment,    │
# │  thorough validation, ethical safeguards, and clinician engagement, ensuring it serves as a trustworthy         │
# │  partner in future healthcare delivery.                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">📋 Analysis: Artificial Intelligence in Healthcare</strong><br>
#         <span style="font-size: 14px; color: #333;">Artificial Intelligence (AI) in healthcare leverages advanced machine learning, natural language processing, robotics, and data analytics to improve diagnosis, treatment, patient monitoring, and management. With roots dating back to early expert systems in the 1970s, AI has recently accelerated due to expansive digital health data and enhanced computational capabilities, particularly through deep learning. AI processes diverse healthcare data, including electronic health records, medical imaging, genomics, and wearable device outputs, enabling new insights such as predictive analytics and personalized medicine. The integration of AI into clinical workflows continues to grow, despite ongoing challenges related to validation, ethics, interoperability, and training.<br><br>Key Points:<br>- Medical Imaging and Diagnostics: Deep learning models like convolutional neural networks (CNNs) have achieved accuracy on par with specialists in detecting conditions such as diabetic retinopathy, breast cancer, and skin cancer from imaging data.<br>- Predictive Analytics and Clinical NLP: AI predicts patient outcomes (e.g., deterioration, readmission risk) and uses natural language processing to extract meaningful information from unstructured clinical notes, enhancing decision support.<br>- Drug Discovery and Robotics: AI accelerates drug development by predicting molecular interactions and supports surgical precision with robotics, exemplified by systems like da Vinci Surgical System.<br>- Ethical and Implementation Challenges: Privacy, bias, algorithm transparency, and interoperability pose significant hurdles, with emerging solutions such as federated learning aimed at addressing data confidentiality and collaborative model training.<br><br>Significance:<br>AI holds transformative potential to improve healthcare accuracy, efficiency, and personalization, reducing costs and enhancing patient outcomes by augmenting clinicians rather than replacing them. Its ability to analyze large-scale, complex health data enables earlier disease detection, faster drug development, and better population health management. However, realizing AI’s full benefits requires responsible deployment, thorough validation, ethical safeguards, and clinician engagement, ensuring it serves as a trustworthy partner in future healthcare delivery.</span>
#     </div>
# CrewOutput(raw='Artificial Intelligence (AI) in healthcare leverages advanced machine learning, natural language processing, robotics, and data analytics to improve diagnosis, treatment, patient monitoring, and management. With roots dating back to early expert systems in the 1970s, AI has recently accelerated due to expansive digital health data and enhanced computational capabilities, particularly through deep learning. AI processes diverse healthcare data, including electronic health records, medical imaging, genomics, and wearable device outputs, enabling new insights such as predictive analytics and personalized medicine. The integration of AI into clinical workflows continues to grow, despite ongoing challenges related to validation, ethics, interoperability, and training.\n\nKey Points:\n- Medical Imaging and Diagnostics: Deep learning models like convolutional neural networks (CNNs) have achieved accuracy on par with specialists in detecting conditions such as diabetic retinopathy, breast cancer, and skin cancer from imaging data.\n- Predictive Analytics and Clinical NLP: AI predicts patient outcomes (e.g., deterioration, readmission risk) and uses natural language processing to extract meaningful information from unstructured clinical notes, enhancing decision support.\n- Drug Discovery and Robotics: AI accelerates drug development by predicting molecular interactions and supports surgical precision with robotics, exemplified by systems like da Vinci Surgical System.\n- Ethical and Implementation Challenges: Privacy, bias, algorithm transparency, and interoperability pose significant hurdles, with emerging solutions such as federated learning aimed at addressing data confidentiality and collaborative model training.\n\nSignificance:\nAI holds transformative potential to improve healthcare accuracy, efficiency, and personalization, reducing costs and enhancing patient outcomes by augmenting clinicians rather than replacing them. Its ability to analyze large-scale, complex health data enables earlier disease detection, faster drug development, and better population health management. However, realizing AI’s full benefits requires responsible deployment, thorough validation, ethical safeguards, and clinician engagement, ensuring it serves as a trustworthy partner in future healthcare delivery.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Research the topic: Artificial Intelligence in Healthcare\n\n        Provide comprehensive information including:\n        1. Key facts and background information\n        2. Important developments and achievements\n        3. Current status and recent context\n        4. Significance and impact\n\n        Use your existing knowledge to provide accurate information.', name='Research the topic: Artificial Intelligence in Healthcare\n\n        Provide comprehensive information including:\n        1. Key facts and background information\n        2. Important developments and achievements\n        3. Current status and recent context\n        4. Significance and impact\n\n        Use your existing knowledge to provide accurate information.', expected_output='Research findings about: Artificial Intelligence in Healthcare', summary='Research the topic: Artificial Intelligence in Healthcare\n\n   ...', raw='Research findings about: Artificial Intelligence in Healthcare\n\n1. Key Facts and Background Information\n\nArtificial Intelligence (AI) in healthcare refers to the application of machine learning algorithms, natural language processing, robotics, and data analytics to assist in diagnosis, treatment, patient monitoring, and healthcare management. AI systems can process and analyze large volumes of health data to extract meaningful insights that help healthcare professionals make more informed decisions.\n\nThe roots of AI in healthcare trace back to early expert systems in the 1970s, such as MYCIN, which was designed to diagnose bacterial infections. However, due t ...

# %% [markdown]
# ## 🔧 Part 2: Adding Tools to Agents
#
# Now let's **extend our lab** by adding tools to make our agents more powerful!
#
# In CrewAI, agents can be equipped with **tools** to perform external tasks such as:
# - Searching the web 🌐
# - Reading from websites 📖
# - Calling APIs 📡
# - Doing calculations 🧮
#
# ### 🛠️ Tool Types in CrewAI
#
# CrewAI supports many tools via `crewai_tools` and `langchain` integration. In this part, we focus on using a **web search tool** that:
# - ✅ Works without requiring an API key
# - 🔓 Is fully integrated with CrewAI
# - 🧠 Allows the agent to gather **current information** from the internet
#
# ---
#
# ### 🌐 WebsiteSearchTool – Free Web Search (No API Key Needed)
#
# The `WebsiteSearchTool` is a built-in tool from `crewai_tools` that allows agents to search the web without credentials. It’s perfect for:
# - Research agents looking for up-to-date content
# - Summarizing recent news and trends
# - Pulling data from publicly accessible websites
#
# ```python
# from crewai_tools import WebsiteSearchTool
#
# search_tool = WebsiteSearchTool()

# %%
from crewai import Agent, Task, Crew
from crewai_tools import WebsiteSearchTool

# 🔍 Create a free web search agent (no API key required)
web_researcher = Agent(
    role="Web Research Agent",
    goal="Gather current online information using free CrewAI web search tool",
    backstory="You research current events with the built-in CrewAI WebsiteSearchTool (no API key needed).",
    tools=[WebsiteSearchTool()],
    verbose=True,
    allow_delegation=False
)

pretty_print("🔍 Web research agent created with WebsiteSearchTool!\n🌐 Can search websites without API keys", "✅ Web Agent Ready", "blue")

# 🎯 Task: perform and analyze search
def search_current_info(topic):
    search_task = Task(
        description=f"Use the free WebsiteSearchTool to search for recent updates on: {topic}",
        expected_output="Raw search results",
        agent=web_researcher
    )
    analysis_task = Task(
        description=f"Analyze the raw search results for: {topic}. Summarize key findings.",
        expected_output="Summary of insights",
        agent=web_researcher
    )
    crew = Crew(agents=[web_researcher], tasks=[search_task, analysis_task], verbose=False)

    pretty_print(f"🔍 Searching for current information about: {topic}", "🚀 Web Search Started", "yellow")

    result = crew.kickoff()

    pretty_print(str(result), f"🌐 Search Results: {topic}", "blue")

    return result
# Out:
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">✅ Web Agent Ready</strong><br>
#         <span style="font-size: 14px; color: #333;">🔍 Web research agent created with WebsiteSearchTool!<br>🌐 Can search websites without API keys</span>
#     </div>

# %%
# 🧪 Example usage:
result = search_current_info("latest AI breakthroughs 2026")
# Out:
#     <div style="border-left: 5px solid #b26a00; padding: 12px 16px; background-color: #fff8e1;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #b26a00; font-size: 16px;">🚀 Web Search Started</strong><br>
#         <span style="font-size: 14px; color: #333;">🔍 Searching for current information about: latest AI breakthroughs 2026</span>
#     </div>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Web Research Agent                                                                                      │
# │                                                                                                                 │
# │  Task: Use the free WebsiteSearchTool to search for recent updates on: latest AI breakthroughs 2026             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_in_a_specific_website executed with result: Relevant Content:
#
# Artificial intelligence This is the most misunderstood graph in AI To some, METR’s “time horizon plot” indicates that AI utopia—or apocalypse—is close at hand. The truth is more com...
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Web Research Agent                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Artificial intelligence This is the most misunderstood graph in AI To some, METR’s “time horizon plot”         │
# │  indicates that AI utopia—or apocalypse—is close at hand. The truth is more complicated.                        │
# │                                                                                                                 │
# │  Artificial intelligence LLMs contain a LOT of parameters. But what’s a parameter? They’re the mysterious       │
# │  numbers that make your favorite AI models tick. What are they and what do they do?                             │
# │                                                                                                                 │
# │  Artificial intelligence How do AI models generate videos? With powerful video generation tools now in the      │
# │  hands of more people than ever, let's take a look at how they work.                                            │
# │                                                                                                                 │
# │  Highlights Culture 3 months 10 Breakthrough Technologies 2026 Here are our picks for the advances to watch in  │
# │  the years ahead—and why we think they matter right now.                                                        │
# │                                                                                                                 │
# │  Artificial intelligence Why AI predictions are so hard And why we're predicting what's next for the            │
# │  technology in 2026 anyway.                                                                                     │
# │                                                                                                                 │
# │  Artificial intelligence What’s next for AI in 2026 Our AI writers make their big bets for the coming           │
# │  year—here are five hot trends to watch.                                                                        │
# │                                                                                                                 │
# │  Artificial intelligence AI materials discovery now needs to move into the real world Startups flush with cash  │
# │  are building AI-assisted laboratories to find materials far faster and more cheaply, but are still waiting     │
# │  for their ChatGPT moment.                                                                                      │
# │                                                                                                                 │
# │  Artificial intelligence OpenAI is throwing everything into building a fully automated researcher An exclusive  │
# │  conversation with OpenAI’s chief scientist, Jakub Pachocki, about his firm's new grand challenge and the       │
# │  future of AI.                                                                                                  │
# │                                                                                                                 │
# │  Artificial intelligence A brief history of Sam Altman’s hype Here’s how pinning a utopian vision for AI on     │
# │  LLMs kicked off the hype cycle that’s causing fears of a bubble today.                                         │
# │                                                                                                                 │
# │  Artificial intelligence AI might not be coming for lawyers’ jobs anytime soon Generative AI might have aced    │
# │  the bar exam, but an LLM still can’t think like a lawyer.                                                      │
# │                                                                                                                 │
# │  Artificial intelligence OpenAI’s “compromise” with the Pentagon is what Anthropic feared Anthropic pushed for  │
# │  moral boundaries. OpenAI settled for softer legal ones, and now it stands to benefit as the Pentagon rushes    │
# │  out a politicized AI strategy during strikes on Iran.                                                          │
# │                                                                                                                 │
# │  Artificial intelligence Microsoft has a new plan to prove what’s real and what’s AI online A new proposal      │
# │  calls on social media and AI companies to adopt strict verification, but the company hasn’t committed to       │
# │  following its own recommendations.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Web Research Agent                                                                                      │
# │                                                                                                                 │
# │  Task: Analyze the raw search results for: latest AI breakthroughs 2026. Summarize key findings.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Web Research Agent                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Artificial intelligence This is the most misunderstood graph in AI To some, METR’s “time horizon plot”         │
# │  indicates that AI utopia—or apocalypse—is close at hand. The truth is more complicated.                        │
# │                                                                                                                 │
# │  Artificial intelligence LLMs contain a LOT of parameters. But what’s a parameter? They’re the mysterious       │
# │  numbers that make your favorite AI models tick. What are they and what do they do?                             │
# │                                                                                                                 │
# │  Artificial intelligence How do AI models generate videos? With powerful video generation tools now in the      │
# │  hands of more people than ever, let's take a look at how they work.                                            │
# │                                                                                                                 │
# │  Highlights Culture 3 months 10 Breakthrough Technologies 2026 Here are our picks for the advances to watch in  │
# │  the years ahead—and why we think they matter right now.                                                        │
# │                                                                                                                 │
# │  Artificial intelligence Why AI predictions are so hard And why we're predicting what's next for the            │
# │  technology in 2026 anyway.                                                                                     │
# │                                                                                                                 │
# │  Artificial intelligence What’s next for AI in 2026 Our AI writers make their big bets for the coming           │
# │  year—here are five hot trends to watch.                                                                        │
# │                                                                                                                 │
# │  Artificial intelligence AI materials discovery now needs to move into the real world Startups flush with cash  │
# │  are building AI-assisted laboratories to find materials far faster and more cheaply, but are still waiting     │
# │  for their ChatGPT moment.                                                                                      │
# │                                                                                                                 │
# │  Artificial intelligence OpenAI is throwing everything into building a fully automated researcher An exclusive  │
# │  conversation with OpenAI’s chief scientist, Jakub Pachocki, about his firm's new grand challenge and the       │
# │  future of AI.                                                                                                  │
# │                                                                                                                 │
# │  Artificial intelligence A brief history of Sam Altman’s hype Here’s how pinning a utopian vision for AI on     │
# │  LLMs kicked off the hype cycle that’s causing fears of a bubble today.                                         │
# │                                                                                                                 │
# │  Artificial intelligence AI might not be coming for lawyers’ jobs anytime soon Generative AI might have aced    │
# │  the bar exam, but an LLM still can’t think like a lawyer.                                                      │
# │                                                                                                                 │
# │  Artificial intelligence OpenAI’s “compromise” with the Pentagon is what Anthropic feared Anthropic pushed for  │
# │  moral boundaries. OpenAI settled for softer legal ones, and now it stands to benefit as the Pentagon rushes    │
# │  out a politicized AI strategy during strikes on Iran.                                                          │
# │                                                                                                                 │
# │  Artificial intelligence Microsoft has a new plan to prove what’s real and what’s AI online A new proposal      │
# │  calls on social media and AI companies to adopt strict verification, but the company hasn’t committed to       │
# │  following its own recommendations.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#     <div style="border-left: 5px solid #1e4b8f; padding: 12px 16px; background-color: #f0f6ff;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #1e4b8f; font-size: 16px;">🌐 Search Results: latest AI breakthroughs 2026</strong><br>
#         <span style="font-size: 14px; color: #333;">Artificial intelligence This is the most misunderstood graph in AI To some, METR’s “time horizon plot” indicates that AI utopia—or apocalypse—is close at hand. The truth is more complicated.<br><br>Artificial intelligence LLMs contain a LOT of parameters. But what’s a parameter? They’re the mysterious numbers that make your favorite AI models tick. What are they and what do they do?<br><br>Artificial intelligence How do AI models generate videos? With powerful video generation tools now in the hands of more people than ever, let's take a look at how they work.<br><br>Highlights Culture 3 months 10 Breakthrough Technologies 2026 Here are our picks for the advances to watch in the years ahead—and why we think they matter right now.<br><br>Artificial intelligence Why AI predictions are so hard And why we're predicting what's next for the technology in 2026 anyway.<br><br>Artificial intelligence What’s next for AI in 2026 Our AI writers make their big bets for the coming year—here are five hot trends to watch.<br><br>Artificial intelligence AI materials discovery now needs to move into the real world Startups flush with cash are building AI-assisted laboratories to find materials far faster and more cheaply, but are still waiting for their ChatGPT moment.<br><br>Artificial intelligence OpenAI is throwing everything into building a fully automated researcher An exclusive conversation with OpenAI’s chief scientist, Jakub Pachocki, about his firm's new grand challenge and the future of AI.<br><br>Artificial intelligence A brief history of Sam Altman’s hype Here’s how pinning a utopian vision for AI on LLMs kicked off the hype cycle that’s causing fears of a bubble today.<br><br>Artificial intelligence AI might not be coming for lawyers’ jobs anytime soon Generative AI might have aced the bar exam, but an LLM still can’t think like a lawyer.<br><br>Artificial intelligence OpenAI’s “compromise” with the Pentagon is what Anthropic feared Anthropic pushed for moral boundaries. OpenAI settled for softer legal ones, and now it stands to benefit as the Pentagon rushes out a politicized AI strategy during strikes on Iran.<br><br>Artificial intelligence Microsoft has a new plan to prove what’s real and what’s AI online A new proposal calls on social media and AI companies to adopt strict verification, but the company hasn’t committed to following its own recommendations.</span>
#     </div>

# %%
# +++++ ✍️ HANDS-ON EXERCISE: Complete the Mathematical Model
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Fill in the 10 blanks to create a working mathematical analysis crew!

# Sample data: Years vs Harvard Nobel Prize winners
sample_data = "2020,2;2021,1;2022,3;2023,2;2024,1"

# Fill in the blanks below (replace ----- with your answers):

# 1. Import the Task class
from crewai import Task, Agent, Crew

# Define the math_agent here, as it's missing
math_agent = Agent(
    role="Mathematical Modeler",
    goal="Perform statistical and mathematical analysis on given data to extract relationships",
    backstory="""You are an expert in statistical modeling, specializing in regression analysis.
    You can identify mathematical relationships in data and quantify their strength."
    """,
    verbose=True,
    allow_delegation=False
)

# 2. Create a mathematical analysis task
math_task = Task(
    description=f"""Analyze the sample data: {sample_data}

    This data shows: Year, Number of Harvard Nobel Prize winners

    Perform linear regression analysis and provide:
    1. The mathematical relationship (slope and intercept)
    2. How well the model fits the data (R-squared)
    3. Brief about what this relationship means

    Remember: NO predictions beyond 2024!""",
    expected_output="Mathematical analysis of the Harvard Nobel Prize data",
    agent=math_agent # 3. Which agent should handle this task?
)

# 4. Create a second agent for interpretation
interpretation_agent = Agent(
    role="Educational Statistics Interpreter",  # 5. What should this agent's role be?
    goal="Interpret mathematical results in educational context",
    backstory="""You are an expert in educational statistics who interprets mathematical
    results for educators. You focus on understanding patterns in existing data.""",
    verbose=True,
    allow_delegation=False # 6. Should this agent delegate? True or False?
)

# 7. Create an interpretation task
interpretation_task = Task(
    description="Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.",
    expected_output="Clear interpretation of the mathematical relationship",
    agent=interpretation_agent  # 8. Which agent should handle this task?
)

# 9. Create a crew with both agents
math_crew = Crew(
    agents=[math_agent, interpretation_agent],  # 10. Add the second agent here
    tasks=[math_task, interpretation_task],
    verbose=True
)

# Test the mathematical crew
print("🧮 Testing Mathematical Model Crew...")
print("="*50)

# Uncomment to run after filling in the blanks:
result = math_crew.kickoff()
pretty_print(str(result), "🧮 Mathematical Analysis", "yellow")

#print("✍️ Complete the 10 blanks above, then uncomment the last 3 lines to run!")
# Out:
# 🧮 Testing Mathematical Model Crew...
# ==================================================
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: db008ca1-970f-4492-bbda-1ae22795ba6a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Brief about what this relationship means                                                                │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │  ID: 4e3f5bd1-34eb-4850-9bf5-dfd617cd775b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │  Task: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Brief about what this relationship means                                                                │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Mathematical analysis of the Harvard Nobel Prize data                                                          │
# │                                                                                                                 │
# │  Given data points (Year, Number of Harvard Nobel Prize winners):                                               │
# │  (2020, 2), (2021, 1), (2022, 3), (2023, 2), (2024, 1)                                                          │
# │                                                                                                                 │
# │  Step 1: Define the variables                                                                                   │
# │                                                                                                                 │
# │  - Independent variable \( x = \) Year (To simplify calculations, convert years to \( x = \text{Year} - 2020    │
# │  \), so we have \(x = 0,1,2,3,4\))                                                                              │
# │  - Dependent variable \( y = \) Number of Nobel Prize winners                                                   │
# │                                                                                                                 │
# │  Re-expressed data:                                                                                             │
# │  \[                                                                                                             │
# │  (0, 2), (1, 1), (2, 3), (3, 2), (4, 1)                                                                         │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Step 2: Calculate sums needed for linear regression                                                            │
# │                                                                                                                 │
# │  Number of points \( n = 5 \)                                                                                   │
# │                                                                                                                 │
# │  Calculate:                                                                                                     │
# │  \[                                                                                                             │
# │  \sum x = 0 + 1 + 2 + 3 + 4 = 10                                                                                │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \sum y = 2 + 1 + 3 + 2 + 1 = 9                                                                                 │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \sum xy = (0)(2) + (1)(1) + (2)(3) + (3)(2) + (4)(1) = 0 + 1 + 6 + 6 + 4 = 17                                  │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \sum x^2 = 0^2 + 1^2 + 2^2 + 3^2 + 4^2 = 0 + 1 + 4 + 9 + 16 = 30                                               │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \sum y^2 = 2^2 + 1^2 + 3^2 + 2^2 + 1^2 = 4 + 1 + 9 + 4 + 1 = 19                                                │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Step 3: Compute slope \( m \) and intercept \( b \) of the regression line \( y = mx + b \)                    │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  m = \frac{n\sum xy - \sum x \sum y}{n \sum x^2 - (\sum x)^2}                                                   │
# │  = \frac{5 \times 17 - 10 \times 9}{5 \times 30 - (10)^2}                                                       │
# │  = \frac{85 - 90}{150 - 100}                                                                                    │
# │  = \frac{-5}{50} = -0.1                                                                                         │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  b = \frac{\sum y - m \sum x}{n}                                                                                │
# │  = \frac{9 - (-0.1) \times 10}{5}                                                                               │
# │  = \frac{9 + 1}{5}                                                                                              │
# │  = \frac{10}{5} = 2.0                                                                                           │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Thus, the linear relationship is                                                                               │
# │  \[                                                                                                             │
# │  y = -0.1x + 2.0                                                                                                │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Or reverting \(x = \text{Year} - 2020\):                                                                       │
# │  \[                                                                                                             │
# │  y = -0.1(\text{Year} - 2020) + 2.0 = -0.1 \times \text{Year} + 202.0                                           │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Step 4: Calculate \( R^2 \), the coefficient of determination                                                  │
# │                                                                                                                 │
# │  First, compute mean of \( y \):                                                                                │
# │  \[                                                                                                             │
# │  \bar{y} = \frac{9}{5} = 1.8                                                                                    │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Total sum of squares (SST):                                                                                    │
# │  \[                                                                                                             │
# │  SST = \sum (y_i - \bar{y})^2 = (2 - 1.8)^2 + (1 - 1.8)^2 + (3 - 1.8)^2 + (2 - 1.8)^2 + (1 - 1.8)^2             │
# │  = 0.04 + 0.64 + 1.44 + 0.04 + 0.64 = 2.8                                                                       │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Sum of squares of residuals (SSR):                                                                             │
# │  First find predicted values \( \hat{y}_i \):                                                                   │
# │  \[                                                                                                             │
# │  \hat{y}_0 = -0.1 \times 0 + 2.0 = 2.0                                                                          │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \hat{y}_1 = -0.1 \times 1 + 2.0 = 1.9                                                                          │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \hat{y}_2 = -0.1 \times 2 + 2.0 = 1.8                                                                          │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \hat{y}_3 = -0.1 \times 3 + 2.0 = 1.7                                                                          │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \hat{y}_4 = -0.1 \times 4 + 2.0 = 1.6                                                                          │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Residuals:                                                                                                     │
# │  \[                                                                                                             │
# │  (2 - 2.0)^2 = 0.0                                                                                              │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  (1 - 1.9)^2 = 0.81                                                                                             │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  (3 - 1.8)^2 = 1.44                                                                                             │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  (2 - 1.7)^2 = 0.09                                                                                             │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  (1 - 1.6)^2 = 0.36                                                                                             │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Sum of squared residuals SSR:                                                                                  │
# │  \[                                                                                                             │
# │  0.0 + 0.81 + 1.44 + 0.09 + 0.36 = 2.7                                                                          │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Coefficient of determination \(R^2\):                                                                          │
# │  \[                                                                                                             │
# │  R^2 = 1 - \frac{SSR}{SST} = 1 - \frac{2.7}{2.8} = 1 - 0.9643 = 0.0357                                          │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Step 5: Interpretation                                                                                         │
# │                                                                                                                 │
# │  1. **Mathematical Relationship:**                                                                              │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  \boxed{                                                                                                        │
# │  y = -0.1 \times (\text{Year} - 2020) + 2.0                                                                     │
# │  }                                                                                                              │
# │  \]                                                                                                             │
# │  or equivalently,                                                                                               │
# │  \[                                                                                                             │
# │  y = -0.1 \times \text{Year} + 202.0                                                                            │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  where \(y\) is the number of Harvard Nobel Prize winners in a given year.                                      │
# │                                                                                                                 │
# │  2. **Model Fit:**                                                                                              │
# │                                                                                                                 │
# │  The \( R^2 \) value is approximately 0.036, indicating that this linear model explains only about 3.6% of the  │
# │  variability in the number of Nobel Prize winners. This is a very weak fit, meaning the linear trend does not   │
# │  capture the data pattern well.                                                                                 │
# │                                                                                                                 │
# │  3. **Meaning:**                                                                                                │
# │                                                                                                                 │
# │  The negative slope suggests a very slight decrease in the number of Nobel Prize winners per year over this     │
# │  period, but because \( R^2 \) is very low, this conclusion is not reliable. The number of winners is highly    │
# │  variable and does not follow a strong linear trend during 2020–2024.                                           │
# │                                                                                                                 │
# │  **Note:** No predictions beyond year 2024 are considered or advised due to limited data and poor linear fit.   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Brief about what this relationship means                                                                │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │  ID: fdc21965-b085-4c0f-800a-cb75e48a24f4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Educational Statistics Interpreter                                                                      │
# │                                                                                                                 │
# │  Task: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Educational Statistics Interpreter                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The regression results describe the relationship between the year (from 2020 to 2024) and the number of        │
# │  Harvard Nobel Prize winners per year through the equation:                                                     │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  y = -0.1 \times (\text{Year} - 2020) + 2.0                                                                     │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  or equivalently,                                                                                               │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  y = -0.1 \times \text{Year} + 202.0                                                                            │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  where:                                                                                                         │
# │  - \( y \) represents the number of Harvard Nobel Prize winners in a particular year,                           │
# │  - and the independent variable is the year adjusted by subtracting 2020 for simplicity.                        │
# │                                                                                                                 │
# │  **Interpretation of the slope (\( m = -0.1 \)):**                                                              │
# │  The slope indicates that for each additional year after 2020, the model estimates a decrease of 0.1 Nobel      │
# │  Prize winners. Practically, this suggests a very slight downward trend in the number of Harvard Nobel Prize    │
# │  winners from year to year over this five-year period. However, a change of 0.1 winners per year is a very      │
# │  small and subtle decline.                                                                                      │
# │                                                                                                                 │
# │  **Interpretation of the intercept (\( b = 2.0 \)):**                                                           │
# │  The intercept represents the predicted number of Nobel Prize winners in the base year 2020 (when \( x=0 \)).   │
# │  According to this model, the expected number of winners in 2020 is exactly 2, which matches the observed data  │
# │  point.                                                                                                         │
# │                                                                                                                 │
# │  **Interpretation of the \( R^2 \) value (~0.036):**                                                            │
# │  The coefficient of determination \( R^2 \), approximately 0.036, means that only about 3.6% of the             │
# │  variability in the annual number of Harvard Nobel Prize winners is explained by this linear trend with year.   │
# │  This is a very low value, indicating that the linear model fits the data poorly and that year-to-year changes  │
# │  in winners are largely unexplained by a simple linear decline.                                                 │
# │                                                                                                                 │
# │  **Overall meaning of the relationship:**                                                                       │
# │  While the slope suggests a small downward trend in the number of Harvard Nobel Prize winners over these        │
# │  years, the very low \( R^2 \) tells us that this trend is not a strong or reliable pattern in the data. The    │
# │  number of winners fluctuates irregularly—with years of increases and decreases—that a straight line does not   │
# │  represent well. Therefore, the relationship between year and number of Harvard Nobel Prize winners during      │
# │  2020–2024 is essentially weak and highly variable, with no strong linear pattern evident.                      │
# │                                                                                                                 │
# │  Given the limited data and the poor fit of the linear trend, we should be cautious in drawing conclusions      │
# │  about any real increase or decrease in winners based on year alone. The data suggests that other factors       │
# │  beyond a simple year progression likely influence the number of Harvard Nobel Prize winners annually.          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │  Agent: Educational Statistics Interpreter                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#     <div style="border-left: 5px solid #b26a00; padding: 12px 16px; background-color: #fff8e1;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #b26a00; font-size: 16px;">🧮 Mathematical Analysis</strong><br>
#         <span style="font-size: 14px; color: #333;">The regression results describe the relationship between the year (from 2020 to 2024) and the number of Harvard Nobel Prize winners per year through the equation:<br><br>\[<br>y = -0.1 \times (\text{Year} - 2020) + 2.0<br>\]<br><br>or equivalently,<br><br>\[<br>y = -0.1 \times \text{Year} + 202.0<br>\]<br><br>where:<br>- \( y \) represents the number of Harvard Nobel Prize winners in a particular year,<br>- and the independent variable is the year adjusted by subtracting 2020 for simplicity.<br><br>**Interpretation of the slope (\( m = -0.1 \)):**  <br>The slope indicates that for each additional year after 2020, the model estimates a decrease of 0.1 Nobel Prize winners. Practically, this suggests a very slight downward trend in the number of Harvard Nobel Prize winners from year to year over this five-year period. However, a change of 0.1 winners per year is a very small and subtle decline.<br><br>**Interpretation of the intercept (\( b = 2.0 \)):**  <br>The intercept represents the predicted number of Nobel Prize winners in the base year 2020 (when \( x=0 \)). According to this model, the expected number of winners in 2020 is exactly 2, which matches the observed data point.<br><br>**Interpretation of the \( R^2 \) value (~0.036):**  <br>The coefficient of determination \( R^2 \), approximately 0.036, means that only about 3.6% of the variability in the annual number of Harvard Nobel Prize winners is explained by this linear trend with year. This is a very low value, indicating that the linear model fits the data poorly and that year-to-year changes in winners are largely unexplained by a simple linear decline.<br><br>**Overall meaning of the relationship:**  <br>While the slope suggests a small downward trend in the number of Harvard Nobel Prize winners over these years, the very low \( R^2 \) tells us that this trend is not a strong or reliable pattern in the data. The number of winners fluctuates irregularly—with years of increases and decreases—that a straight line does not represent well. Therefore, the relationship between year and number of Harvard Nobel Prize winners during 2020–2024 is essentially weak and highly variable, with no strong linear pattern evident.<br><br>Given the limited data and the poor fit of the linear trend, we should be cautious in drawing conclusions about any real increase or decrease in winners based on year alone. The data suggests that other factors beyond a simple year progression likely influence the number of Harvard Nobel Prize winners annually.</span>
#     </div>

# %%
# +++++ ✅ ANSWER KEY - Mathematical Model Solution
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Complete solution for the hands-on exercise

# ANSWERS:
# 1. Task
# 2. Summary (or "Interpretation")
# 3. math_agent
# 4. Any role related to interpretation (e.g., "Data Interpreter")
# 5. "Statistical Interpreter" (or similar)
# 6. False
# 7. interpretation_task
# 8. interpretation_agent
# 9. math_crew
# 10. interpretation_agent

# Here's the complete working solution:
from crewai import Task

sample_data = "2020,2;2021,1;2022,3;2023,2;2024,1"

math_task = Task(
    description=f"""Analyze the sample data: {sample_data}

    This data shows: Year, Number of Harvard Nobel Prize winners

    Perform linear regression analysis and provide:
    1. The mathematical relationship (slope and intercept)
    2. How well the model fits the data (R-squared)
    3. Summary of what this relationship means

    Remember: NO predictions beyond 2024!""",
    expected_output="Mathematical analysis of the Harvard Nobel Prize data",
    agent=math_agent
)

interpretation_agent = Agent(
    role="Statistical Interpreter",
    goal="Interpret mathematical results in educational context",
    backstory="""You are an expert in educational statistics who interprets mathematical
    results for educators. You focus on understanding patterns in existing data.""",
    verbose=True,
    allow_delegation=False
)

interpretation_task = Task(
    description="Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.",
    expected_output="Clear interpretation of the mathematical relationship",
    agent=interpretation_agent
)

math_crew = Crew(
    agents=[math_agent, interpretation_agent],
    tasks=[math_task, interpretation_task],
    verbose=True
)

# Run the complete mathematical analysis
result = math_crew.kickoff()
pretty_print(str(result), "🧮 Complete Mathematical Analysis", "yellow")
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 703d7f55-4bdb-4530-9043-99fbf638212b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Summary of what this relationship means                                                                 │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │  ID: 2d5f2f12-beac-4a45-be1b-5f8853b515fb                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │  Task: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Summary of what this relationship means                                                                 │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Given Data:                                                                                                    │
# │  Year (X) | Number of Harvard Nobel Prize Winners (Y)                                                           │
# │  2020 | 2                                                                                                       │
# │  2021 | 1                                                                                                       │
# │  2022 | 3                                                                                                       │
# │  2023 | 2                                                                                                       │
# │  2024 | 1                                                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Step 1: Set up the data for regression                                                                     │
# │                                                                                                                 │
# │  Let \( x \) be the year. Since year values are large and close, we center the year to improve numerical        │
# │  stability:                                                                                                     │
# │  Let \( x' = \text{Year} - 2020 \) (so \( x' = 0,1,2,3,4 \)).                                                   │
# │                                                                                                                 │
# │  | \(x'\) | \(Y\) |                                                                                             │
# │  |--------|-------|                                                                                             │
# │  | 0      | 2     |                                                                                             │
# │  | 1      | 1     |                                                                                             │
# │  | 2      | 3     |                                                                                             │
# │  | 3      | 2     |                                                                                             │
# │  | 4      | 1     |                                                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Step 2: Compute means                                                                                      │
# │  \[                                                                                                             │
# │  \bar{x'} = \frac{0 + 1 + 2 + 3 + 4}{5} = \frac{10}{5} = 2                                                      │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  \bar{Y} = \frac{2 + 1 + 3 + 2 + 1}{5} = \frac{9}{5} = 1.8                                                      │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Step 3: Compute slope \(b\) and intercept \(a\) for the regression line:                                   │
# │  \[                                                                                                             │
# │  b = \frac{\sum (x'_i - \bar{x'})(Y_i - \bar{Y})}{\sum (x'_i - \bar{x'})^2}                                     │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  a = \bar{Y} - b \bar{x'}                                                                                       │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Calculate numerator for slope:                                                                                 │
# │                                                                                                                 │
# │  | \(x'_i\) | \(Y_i\) | \(x'_i - \bar{x'}\) | \(Y_i - \bar{Y}\) | \((x'_i - \bar{x'})(Y_i - \bar{Y})\) |        │
# │  |----------|---------|---------------------|-------------------|------------------------------------|          │
# │  | 0        | 2       | 0 - 2 = -2          | 2 - 1.8 = 0.2     | (-2)(0.2) = -0.4                   |          │
# │  | 1        | 1       | 1 - 2 = -1          | 1 - 1.8 = -0.8    | (-1)(-0.8) = 0.8                   |          │
# │  | 2        | 3       | 2 - 2 = 0           | 3 - 1.8 = 1.2     | (0)(1.2) = 0                      |           │
# │  | 3        | 2       | 3 - 2 = 1           | 2 - 1.8 = 0.2     | (1)(0.2) = 0.2                    |           │
# │  | 4        | 1       | 4 - 2 = 2           | 1 - 1.8 = -0.8    | (2)(-0.8) = -1.6                  |           │
# │                                                                                                                 │
# │  Sum numerator = -0.4 + 0.8 + 0 + 0.2 - 1.6 = -1.0                                                              │
# │                                                                                                                 │
# │  Calculate denominator for slope:                                                                               │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  \sum (x'_i - \bar{x'})^2 = (-2)^2 + (-1)^2 + 0^2 + 1^2 + 2^2 = 4 + 1 + 0 + 1 + 4 = 10                          │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Thus,                                                                                                          │
# │  \[                                                                                                             │
# │  b = \frac{-1.0}{10} = -0.1                                                                                     │
# │  \]                                                                                                             │
# │  \[                                                                                                             │
# │  a = 1.8 - (-0.1)(2) = 1.8 + 0.2 = 2.0                                                                          │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Step 4: Regression equation (using centered years)                                                         │
# │  \[                                                                                                             │
# │  Y = 2.0 - 0.1 x'                                                                                               │
# │  \]                                                                                                             │
# │  Recall \( x' = \text{Year} - 2020 \), so expressed in original year units:                                     │
# │  \[                                                                                                             │
# │  Y = 2.0 - 0.1(\text{Year} - 2020) = 2.0 - 0.1 \times \text{Year} + 202.0 = (204.0) - 0.1 \times \text{Year}    │
# │  \]                                                                                                             │
# │  But this is less intuitive because of the large intercept. Better to keep the centered form for                │
# │  interpretation.                                                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Step 5: Calculate \( R^2 \) to measure goodness of fit                                                     │
# │                                                                                                                 │
# │  Total Sum of Squares (SST):                                                                                    │
# │  \[                                                                                                             │
# │  SST = \sum (Y_i - \bar{Y})^2                                                                                   │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  | \(Y_i\) | \(Y_i - \bar{Y}\) | \((Y_i - \bar{Y})^2\) |                                                        │
# │  |---------|-------------------|----------------------|                                                         │
# │  | 2       | 0.2               | 0.04                 |                                                         │
# │  | 1       | -0.8              | 0.64                 |                                                         │
# │  | 3       | 1.2               | 1.44                 |                                                         │
# │  | 2       | 0.2               | 0.04                 |                                                         │
# │  | 1       | -0.8              | 0.64                 |                                                         │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  SST = 0.04 + 0.64 + 1.44 + 0.04 + 0.64 = 2.8                                                                   │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Regression Sum of Squares (SSR):                                                                               │
# │  \[                                                                                                             │
# │  SSR = \sum (\hat{Y_i} - \bar{Y})^2                                                                             │
# │  \]                                                                                                             │
# │  Where \(\hat{Y_i} = a + b(x'_i) = 2.0 - 0.1 x'_i\):                                                            │
# │                                                                                                                 │
# │  | \(x'_i\) | \(\hat{Y_i}\)            | \(\hat{Y_i} - \bar{Y}\) | \((\hat{Y_i} - \bar{Y})^2\) |                │
# │  |----------|---------------------------|-------------------------|-----------------------------|               │
# │  | 0        | 2.0 - 0.1(0) = 2.0       | 2.0 - 1.8 = 0.2         | 0.04                        |                │
# │  | 1        | 2.0 - 0.1(1) = 1.9       | 1.9 - 1.8 = 0.1         | 0.01                        |                │
# │  | 2        | 2.0 - 0.1(2) = 1.8       | 1.8 - 1.8 = 0           | 0                           |                │
# │  | 3        | 2.0 - 0.1(3) = 1.7       | 1.7 - 1.8 = -0.1        | 0.01                        |                │
# │  | 4        | 2.0 - 0.1(4) = 1.6       | 1.6 - 1.8 = -0.2        | 0.04                        |                │
# │                                                                                                                 │
# │  \[                                                                                                             │
# │  SSR = 0.04 + 0.01 + 0 + 0.01 + 0.04 = 0.10                                                                     │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Residual Sum of Squares (SSE):                                                                                 │
# │  \[                                                                                                             │
# │  SSE = \sum (Y_i - \hat{Y_i})^2 = SST - SSR = 2.8 - 0.10 = 2.7                                                  │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  Coefficient of Determination:                                                                                  │
# │  \[                                                                                                             │
# │  R^2 = \frac{SSR}{SST} = \frac{0.10}{2.8} \approx 0.0357                                                        │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Final Results:                                                                                             │
# │                                                                                                                 │
# │  1. **Mathematical relationship:**                                                                              │
# │  \[                                                                                                             │
# │  \boxed{                                                                                                        │
# │  \text{Number of Nobel Prize Winners} = 2.0 - 0.1 \times (\text{Year} - 2020)                                   │
# │  }                                                                                                              │
# │  \]                                                                                                             │
# │                                                                                                                 │
# │  2. **Goodness of fit:**                                                                                        │
# │  \[                                                                                                             │
# │  R^2 \approx 0.036                                                                                              │
# │  \]                                                                                                             │
# │  This means only about 3.6% of the variation in the number of winners is explained by the year in this linear   │
# │  model.                                                                                                         │
# │                                                                                                                 │
# │  3. **Interpretation summary:**                                                                                 │
# │  The linear regression suggests a very slight decreasing trend (a slope of -0.1) in the number of Harvard       │
# │  Nobel Prize winners from 2020 to 2024, with an intercept of 2 winners at 2020. However, the model fits the     │
# │  data poorly, as indicated by a very low \( R^2 \) value of 0.036. This means that year alone does not explain  │
# │  the fluctuations in the number of winners in this short time frame; other factors likely play a significant    │
# │  role. The relationship is essentially weak and not statistically meaningful for interpretation or forecasting  │
# │  within the data range, and no predictions beyond 2024 are provided as requested.                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Complete mathematical analysis of the Harvard Nobel Prize data is provided above.**                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Analyze the sample data: 2020,2;2021,1;2022,3;2023,2;2024,1                                              │
# │                                                                                                                 │
# │      This data shows: Year, Number of Harvard Nobel Prize winners                                               │
# │                                                                                                                 │
# │      Perform linear regression analysis and provide:                                                            │
# │      1. The mathematical relationship (slope and intercept)                                                     │
# │      2. How well the model fits the data (R-squared)                                                            │
# │      3. Summary of what this relationship means                                                                 │
# │                                                                                                                 │
# │      Remember: NO predictions beyond 2024!                                                                      │
# │  Agent: Mathematical Modeler                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │  ID: 532ba4e8-f4c3-41ce-b257-78bc86ec18c7                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Statistical Interpreter                                                                                 │
# │                                                                                                                 │
# │  Task: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Statistical Interpreter                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The given regression analysis examines the relationship between the year (from 2020 to 2024) and the number    │
# │  of Harvard Nobel Prize winners each year.                                                                      │
# │                                                                                                                 │
# │  ### Interpretation of the Regression Components:                                                               │
# │                                                                                                                 │
# │  1. **Intercept (a = 2.0):**                                                                                    │
# │     The intercept is the predicted number of winners when \( x' = 0 \), which corresponds to the year 2020      │
# │  (since \( x' = \text{Year} - 2020 \)). This means the model estimates there were 2 Nobel Prize winners from    │
# │  Harvard in 2020.                                                                                               │
# │                                                                                                                 │
# │  2. **Slope (b = -0.1):**                                                                                       │
# │     The slope indicates the average change in the number of Nobel Prize winners per one-year increase from      │
# │  2020 to 2024. A slope of -0.1 means that, on average, the model predicts a decrease of 0.1 winners per year.   │
# │  This is a very small negative trend, suggesting a slight decrease in the number of winners over time.          │
# │                                                                                                                 │
# │  3. **Regression Equation:**                                                                                    │
# │     \[                                                                                                          │
# │     \text{Number of Winners} = 2.0 - 0.1 \times (\text{Year} - 2020)                                            │
# │     \]                                                                                                          │
# │     This equation can be used to estimate the number of Harvard Nobel Prize winners in any year between 2020    │
# │  and 2024. For example, for 2022 (\( x' = 2 \)), the predicted number of winners would be:                      │
# │     \[                                                                                                          │
# │     2.0 - 0.1 \times 2 = 1.8 \text{ winners}                                                                    │
# │     \]                                                                                                          │
# │     which closely aligns with the actual data.                                                                  │
# │                                                                                                                 │
# │  4. **Coefficient of Determination (\( R^2 \approx 0.036 \)):**                                                 │
# │     The \( R^2 \) value measures how well the linear model explains the variation in the observed data. Here,   │
# │  an \( R^2 \) of approximately 0.036 means only about 3.6% of the variation in the number of winners is         │
# │  explained by the change in year. In other words, the year variable accounts for very little of the             │
# │  fluctuations in annual Nobel Prize winners.                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Summary of Relationship in the Data:                                                                       │
# │                                                                                                                 │
# │  - The data shows a very weak linear decreasing trend in the number of Harvard Nobel Prize winners from 2020    │
# │  to 2024, with an estimated decline of 0.1 winners per year.                                                    │
# │  - The intercept indicates about 2 winners at the starting point in 2020.                                       │
# │  - However, the very low \( R^2 \) implies that this linear relationship does not capture the true patterns in  │
# │  the data well; the year alone is a poor predictor of the number of winners.                                    │
# │  - Annual fluctuations appear largely unrelated to time within this short range, implying other factors not     │
# │  included in this model likely drive changes in the number of Nobel Prize winners each year.                    │
# │  - Given this weak and unreliable relationship, this model should not be used to make forecasts beyond the      │
# │  provided data years.                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **In conclusion, although a slight negative slope suggests a small downward trend in Harvard Nobel Prize       │
# │  winners from 2020 to 2024, the relationship between year and number of winners is very weak. Year-by-year      │
# │  variations mostly do not follow a clear linear pattern, so time alone does not explain changes in Nobel        │
# │  recognitions during this period.**                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Interpret the mathematical regression results. Explain what the slope, intercept, and R-squared mean in  │
# │  the context of Harvard Nobel Prize winners. Focus on describing the relationship in the data only.             │
# │  Agent: Statistical Interpreter                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#     <div style="border-left: 5px solid #b26a00; padding: 12px 16px; background-color: #fff8e1;
#                 border-radius: 6px; font-family: 'Segoe UI', sans-serif; line-height: 1.6; margin: 10px 0;">
#         <strong style="color: #b26a00; font-size: 16px;">🧮 Complete Mathematical Analysis</strong><br>
#         <span style="font-size: 14px; color: #333;">The given regression analysis examines the relationship between the year (from 2020 to 2024) and the number of Harvard Nobel Prize winners each year.<br><br>### Interpretation of the Regression Components:<br><br>1. **Intercept (a = 2.0):**  <br>   The intercept is the predicted number of winners when \( x' = 0 \), which corresponds to the year 2020 (since \( x' = \text{Year} - 2020 \)). This means the model estimates there were 2 Nobel Prize winners from Harvard in 2020.<br><br>2. **Slope (b = -0.1):**  <br>   The slope indicates the average change in the number of Nobel Prize winners per one-year increase from 2020 to 2024. A slope of -0.1 means that, on average, the model predicts a decrease of 0.1 winners per year. This is a very small negative trend, suggesting a slight decrease in the number of winners over time.<br><br>3. **Regression Equation:**  <br>   \[<br>   \text{Number of Winners} = 2.0 - 0.1 \times (\text{Year} - 2020)<br>   \]<br>   This equation can be used to estimate the number of Harvard Nobel Prize winners in any year between 2020 and 2024. For example, for 2022 (\( x' = 2 \)), the predicted number of winners would be:<br>   \[<br>   2.0 - 0.1 \times 2 = 1.8 \text{ winners}<br>   \]<br>   which closely aligns with the actual data.<br><br>4. **Coefficient of Determination (\( R^2 \approx 0.036 \)):**  <br>   The \( R^2 \) value measures how well the linear model explains the variation in the observed data. Here, an \( R^2 \) of approximately 0.036 means only about 3.6% of the variation in the number of winners is explained by the change in year. In other words, the year variable accounts for very little of the fluctuations in annual Nobel Prize winners.<br><br>---<br><br>### Summary of Relationship in the Data:<br><br>- The data shows a very weak linear decreasing trend in the number of Harvard Nobel Prize winners from 2020 to 2024, with an estimated decline of 0.1 winners per year.<br>- The intercept indicates about 2 winners at the starting point in 2020.<br>- However, the very low \( R^2 \) implies that this linear relationship does not capture the true patterns in the data well; the year alone is a poor predictor of the number of winners.<br>- Annual fluctuations appear largely unrelated to time within this short range, implying other factors not included in this model likely drive changes in the number of Nobel Prize winners each year.<br>- Given this weak and unreliable relationship, this model should not be used to make forecasts beyond the provided data years.<br><br>---<br><br>**In conclusion, although a slight negative slope suggests a small downward trend in Harvard Nobel Prize winners from 2020 to 2024, the relationship between year and number of winners is very weak. Year-by-year variations mostly do not follow a clear linear pattern, so time alone does not explain changes in Nobel recognitions during this period.**</span>
#     </div>

# %% [markdown]
# ## 🎓 Lab Summary
#
# ### What You've Learned:
# 1. **🤖 2-Agent System**: Created research and analysis agents
# 2. **🔧 Web Search Tool**: Added real-time information gathering
# 3. **🧮 Mathematical Tool**: Built custom regression analysis capability
# 4. **🛡️ Guardrails**: Implemented safety measures against speculation
# 5. **✍️ Hands-On Practice**: Completed a fill-in-the-blanks exercise
#
# ### Key Concepts:
# - **Tool Integration**: How to add capabilities to agents
# - **Task Coordination**: Sequential workflow between agents
# - **Prompt Optimization**: Consistent, clear instructions
# - **Safety Measures**: Preventing inappropriate predictions
#
# ### 🚀 Next Steps:
# - Try different tools (file processing, API calls, etc.)
# - Experiment with more complex mathematical models
# - Create domain-specific agents for your field
# - Build multi-agent workflows for your projects
#
# **Congratulations! You've mastered CrewAI with tools and mathematical modeling! 🎉**
